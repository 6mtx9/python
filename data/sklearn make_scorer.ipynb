# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(0)

m=100
X = np.linspace(0,4,m).reshape((m,1))
y = 2 + X**1.3 + np.random.randn(m,1)
y = y.ravel()

plt.scatter(X,y)
plt.xlabel('X')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')
